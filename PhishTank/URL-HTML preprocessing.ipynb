# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Loading  
data = pd.read_csv("/content/drive/MyDrive/Phishing/PhishTank/URL-HTML/url_features.csv")

data
# Out:
#                                             Domain  Have IP  Have @  \
# 0                                 graphicriver.net        0       0
# 1                                        ecnavi.jp        0       0
# 2                                     hubpages.com        0       0
# 3                                  extratorrent.cc        0       0
# 4                                    icicibank.com        0       0
# ...                                            ...      ...     ...
# 11932                             sites.google.com        0       0
# 11933                             sites.google.com        0       0
# 11934             habbocreditosparati.blogspot.com        0       0
# 11935  creditiperhabbogratissicuro100.blogspot.com        0       0
# 11936                           aijcs.blogspot.com        0       0
#
#        URL Length  URL Depth  Redirection  https Domain  TinyURL  \
# 0               1          1            0             0        0
# ...

# %%
data.info

# %%
# Class Distribution of Labels
data.groupby('Label').size()
# Out:
# Label
# 0    6500
# 1    5437
# dtype: int64

# %%
df_new = data[data['Special Characters'] != -1]

# %%
df_new
# Out:
#                                             Domain  Have IP  Have @  \
# 0                                 graphicriver.net        0       0
# 1                                        ecnavi.jp        0       0
# 2                                     hubpages.com        0       0
# 3                                  extratorrent.cc        0       0
# 4                                    icicibank.com        0       0
# ...                                            ...      ...     ...
# 11932                             sites.google.com        0       0
# 11933                             sites.google.com        0       0
# 11934             habbocreditosparati.blogspot.com        0       0
# 11935  creditiperhabbogratissicuro100.blogspot.com        0       0
# 11936                           aijcs.blogspot.com        0       0
#
#        URL Length  URL Depth  Redirection  https Domain  TinyURL  \
# 0               1          1            0             0        0
# ...

# %%
# Class Distribution of Labels
df_new.groupby('Label').size()
# Out:
# Label
# 0    5828
# 1    4509
# dtype: int64

# %%
# Storing the extracted legitimate URLs fatures to csv file
df_new.to_csv('/content/drive/MyDrive/Phishing/PhishTank/URL-HTML/preprocessed_url_features.csv')
